# %%
# 변수는 어떻게 만들까? 

a = 1
b = "python"
c = [1, 2, 3]

# %%
import builtins
print = builtins.print

# %%
# 변수명 규칙
# 1. 영문자, 숫자, 언더스코어(_)만 사용할 수 있다. 
# 2. 숫자로 시작할 수 없다.
# 3. 예약어는 사용할 수 없다. 
# 4. 대소문자를 구분한다. 

Abc = 1
abc = 2

print(Abc)
print(abc)
# Out:
# 1
# 2

# %%
(a, b) = ("python", "Life")

# %%
print(a)
print(b)
# Out:
# python
# Life

# %%
a, b = ["python", "life"]
print(a) 
print(b)
# Out:
# python
# life
