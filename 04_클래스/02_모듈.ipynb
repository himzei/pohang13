# %%
import mod1

mod1.add(3, 4)
mod1.sub(4, 3)
# Out:
# 1

# %%
from mod1 import add, sub

print(add(7, 10))
print(sub(10, 3))
# Out:
# 17
# 7

# %%
from mod1 import *

print(add(10, 10))
# Out:
# 20

# %%
from mod1 import add

add(3, 4)
# Out:
# 7
