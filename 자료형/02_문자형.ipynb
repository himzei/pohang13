# %%
a = 3
print("Life is too short, You need Python")
print("a")
print("123")
# Out:
# Life is too short, You need Python
# a
# 123

# %%
# 작은따옴표
'python is fun'
# Out:
# 'python is fun'

# %%
# 큰따옴표 3개 연속
"""life is too short, 
you need python"""
# Out:
# 'life is too short, you need python'

# %%
# 작은따옴표 3개 연속
'''life is too short, 
you need python'''
# Out:
# 'life is too short, \nyou need python'

# %%
"Python's favorite food is perl"
# Out:
# "Python's favorite food is perl"

# %%
print('"Python is very easy" he says')
# Out:
# "Python is very easy" he says

# %%
# 역슬래시를 이용해서 작은따옴표와 큰따옴표를 문자열에 포함
food = "python\'s favorite \n is \tperl"
print(food)

# \n 줄을 바꿀때
# \t 탭간격을 줄때
# \\ \를 그대로 사용할때
# \' 작은 따옴표를 그대로 표현할때
# Out:
# python's favorite
#  is 	perl

# %%
# 문자열 연산하기 
head = "Python" 
tail = " is fun"

head + tail
# Out:
# 'Python is fun'

# %%
a = "Python" 
a * 3
# Out:
# 'PythonPythonPython'

# %%
# 문자열 길이 구하기
a = "Life is too short" 
# len("Life is too short")
len(a)
# Out:
# 17

# %%
# 문자열 인덱싱
a = "Life is too short"
print(a[8])
print(a[-1])
print(a[-2])
# Out:
# t
# t
# r

# %%
# 문자열 슬라이싱
a = '''life is too short, you need python'''

print(a[0:4])
print(a[12:17])
print(a[5:])
print(a[:17])
print(a[:])
# Out:
# 'life is too short, you need python'

# %%
# 문자열 변수 출력

day = "four" 
print(f"I was sick for {day} days")
# Out:
# I was sick for four days

# %% [markdown]
# **1번.** 파이썬에서 숫자형 자료형 4가지를 모두 쓰시오.
#
# **2번.** 다음 중 정수형(int)에 해당하는 값을 모두 고르시오.
#
# `123, 3.14, -45, 0o25, 0xFF, 1.0, -7`
#
# **3번.** `0o25`는 어떤 진법의 숫자인가? 이를 10진수로 변환하면?
#
# **4번.** `0xFF`는 어떤 진법의 숫자인가? 이를 10진수로 변환하면?
#
# **1번.** 파이썬에서 문자열을 만드는 4가지 방법을 쓰시오.
#
# **2번.** 다음 문자열을 출력하려면 어떻게 코드를 작성해야 하는가?
#
# `Python's favorite food is perl`
#
# **3번.** 다음 문자열을 출력하려면 어떻게 코드를 작성해야 하는가?
#
# `"Python is very easy." he says.`
#
# **4번.** 여러 줄의 문자열을 변수에 저장하는 2가지 방법을 쓰시오.
#
# `Life is too short
# You need python`
