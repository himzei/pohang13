# %%
# 정수형 

a = 123 
b = -178
c = 0
print(a)
print(b)
print(c)
type(a)
# Out:
# 123
# -178
# 0
# int

# %%
# 실수형
a = 1.2
b = -3.45
print(a)
print(b)
type(a)
# Out:
# 1.2
# -3.45
# float

# %%
# 8진수와 16진수

a = 0o123
print(a)

b = 0x111

1 * 16**2 + 1 * 16 + 1
print(b)

0xF
# Out:
# 83
# 273
# 15
